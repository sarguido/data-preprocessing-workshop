# %% [markdown]
# # Data preprocessing start to finish
#
# In this exercise, let's apply everything we've learned to a dataset about UFO sightings and build a model. There's no "right answer" here. Feel free to use whichever preprocessing techniques you'd like. Some suggestions are:
#
# - Investigating column types
# - Removing missing data
# - Standardizing features
# - Extracting numbers from strings
# - Encoding categorical variables
# - Removing redundant features
# - Removing correlated features
#
# Once you've experimented with some preprocessing techniques, feel free to experiment with modeling! We'll spend the last 10 minutes or so talking as a group about our choices and, if we have a chance, the models we experimented with.

# %%
import pandas as pd

dir_string = "../../datasets/"

ufo = pd.read_csv(dir_string + "ufo_sightings_large.csv")
ufo.head()
# Out:
#                date              city state country      type    seconds  \
# 0   11/3/2011 19:21         woodville    wi      us   unknown  1209600.0
# 1   10/3/2004 19:05         cleveland    oh      us    circle       30.0
# 2   9/25/2009 21:00       coon rapids    mn      us     cigar        0.0
# 3  11/21/2002 05:45          clemmons    nc      us  triangle      300.0
# 4   8/19/2010 12:55  calgary (canada)    ab      ca      oval        0.0
#
#     length_of_time                                               desc  \
# 0          2 weeks  Red blinking objects similar to airplanes or s...
# 1           30sec.               Many fighter jets flying towards UFO
# 2              NaN  Green&#44 red&#44 and blue pulses of light tha...
# 3  about 5 minutes  It was a large&#44 triangular shaped flying ob...
# 4                2     A white spinning disc in the shape of an oval.
#
#      recorded         lat        long
# 0  12/12/2011  44.9530556  -92.291111
# ...
